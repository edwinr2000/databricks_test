# %% [markdown]
# **Esto es una mini prueba**

# %%
from pyspark.sql import Row

data = [
    Row(nombre="Juan", edad=15),
    Row(nombre="Ana", edad=16),
    Row(nombre="Luis", edad=14),
    Row(nombre="Sofia", edad=17)
]

df = spark.createDataFrame(data)
display(df)
